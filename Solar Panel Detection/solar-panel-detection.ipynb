# %%
# !pip install Pillow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 11.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.6/154.6 kB 3.2 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 9.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 13.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 13.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 13.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install captum
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2022WI folder and put all the files under A3 folder, then '2022WI/A3'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Solar Panel Detection'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.5 MB/s eta 0:00:0000:0100:01
# ...
# ['yolov8m.pt:Zone.Identifier', 'yolov8x.pt:Zone.Identifier', 'yolov8m.pt', 'yolov8x.pt']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %%
cd 'drive/My Drive/Solar Panel Detection'
# Out:
# /content/drive/My Drive/Solar Panel Detection

# %%
print(os.listdir('/content/drive/My Drive/Solar Panel Detection/valid/images'))
# Out:
# ['DJI_0753_MP4-24_jpg.rf.726989d4c1c645fb79334ef22830bb2a.jpg', 'DJI_0753_MP4-48_jpg.rf.549c19ca5d80e2e2689e9dc5ad4fad3a.jpg', 'DJI_0753_MP4-41_jpg.rf.9345fe84abc78e77602a8cdc5df85ab1.jpg', 'DJI_0753_MP4-53_jpg.rf.d87385de528b195db129f9440eb7142d.jpg', 'DJI_0753_MP4-29_jpg.rf.e2f444ab0c63ebc6f29c8a70c94ac739.jpg']

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/drive/MyDrive/Solar Panel Detection/runs/detect/train0013/weights/best.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="data.yaml", epochs=20)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.98 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
print(os.listdir('/content/drive/My Drive/Solar Panel Detection/georeferencing'))
# Out:
# ['DJI_0753_MP4-17_jpg.rf.22e284b060d7490329f3e35d8223a929.txt', 'DJI_0753.MP4']

# %%
# prompt: use model to evaluate a the video in the georefrencing folder
from ultralytics import YOLO

# Load a model
model = YOLO("./runs/detect/train0013/weights/best.pt")  # load a pretrained model (recommended for training)


# Use the model
model("./georeferencing/DJI_0753.MP4")  # evaluate model performance on the validation set
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/tpickup/projects/solar-panel-detection/Solar Panel Detection/solar-panel-detection.ipynb Cell 9 line 9
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tpickup/projects/solar-panel-detection/Solar%20Panel%20Detection/solar-panel-detection.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> model = YOLO("./runs/detect/train0013/weights/best.pt")  # load a pretrained model (recommended for training)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tpickup/projects/solar-panel-detection/Solar%20Panel%20Detection/solar-panel-detection.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # Use the model
# ...
